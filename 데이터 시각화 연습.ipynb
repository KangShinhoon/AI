# %%
import pandas as pd
df_data=pd.read_csv("based_data.csv", encoding="cp949")
df_data.shape #1003 x 6
# Out:
# (1003, 6)

# %%
df_data.head()
# Out:
#          Date      Cost  Year  Month  Day  week
# 0  2019-07-03  12040631  2019      7    3     3
# 1  2019-07-04   7314019  2019      7    4     4
# 2  2019-07-05   7502285  2019      7    5     5
# 3  2019-07-06   8077689  2019      7    6     6
# 4  2019-07-07   8085593  2019      7    7     7

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1003 non-null   object
#  1   Cost    1003 non-null   int64
#  2   Year    1003 non-null   int64
#  3   Month   1003 non-null   int64
#  4   Day     1003 non-null   int64
#  5   week    1003 non-null   int64
# dtypes: int64(5), object(1)
# memory usage: 47.1+ KB

# %%
df_data.isnull().sum()
# Out:
# Date     0
# Cost     0
# Year     0
# Month    0
# Day      0
# week     0
# dtype: int64

# %%
df_data["Cost"].describe().round()
# Out:
# count        1003.0
# mean      6548977.0
# std       1491151.0
# min       3521456.0
# 25%       5420850.0
# 50%       6236871.0
# 75%       7611880.0
# max      12040631.0
# Name: Cost, dtype: float64

# %%
df_data.groupby(["Year"])["Cost"].describe().round() #년간
# Out:
#       count       mean        std        min        25%        50%        75%  \
# Year
# 2019  182.0  6021240.0  1611983.0  3521456.0  4536760.0  6038616.0  7095484.0
# 2020  366.0  6466752.0  1424796.0  4056355.0  5315466.0  6097549.0  7537413.0
# 2021  365.0  6816716.0  1446744.0  3545962.0  5745672.0  6352736.0  8077374.0
# 2022   90.0  6864731.0  1367796.0  4596801.0  5793290.0  6545734.0  7938110.0
#
#              max
# Year
# 2019  12040631.0
# 2020  10469249.0
# 2021  10653581.0
# 2022   9774631.0

# %%
df_data.groupby(["Month"])["Cost"].describe().round() #월간
# Out:
#        count       mean        std        min        25%        50%  \
# Month
# 1       93.0  6375550.0  1531923.0  3545962.0  5095413.0  6160355.0
# 2       85.0  6628139.0  1426196.0  4399400.0  5482191.0  6247508.0
# 3       93.0  6683738.0  1407750.0  4755403.0  5675810.0  6110748.0
# 4       60.0  6682726.0  1429163.0  4758608.0  5547442.0  6194588.0
# 5       62.0  6737818.0  1454239.0  4833533.0  5568230.0  6141660.0
# 6       60.0  6446247.0  1389088.0  4638007.0  5402064.0  5876535.0
# 7       91.0  6658590.0  1465183.0  4537289.0  5524823.0  6294429.0
# 8       93.0  7047088.0  1368656.0  3922242.0  6077368.0  6738859.0
# 9       90.0  6806593.0  1707136.0  3798186.0  5632871.0  6608578.0
# 10      93.0  6030676.0  1358159.0  3521456.0  5020301.0  5769813.0
# 11      90.0  5694009.0  1472132.0  3598151.0  4552031.0  5273530.0
# 12      93.0  6860402.0  1356020.0  4390425.0  5972891.0  6564762.0
#
#              75%         max
# Month
# 1      7290530.0  10653581.0
# ...

# %%
df_data.groupby(["Day"])["Cost"].describe().round() #일간
# Out:
#      count       mean        std        min        25%        50%        75%  \
# Day
# 1     32.0  6531519.0  1482511.0  3960002.0  5376133.0  6281200.0  7586315.0
# 2     32.0  6374316.0  1326892.0  4153108.0  5288851.0  6409702.0  7379056.0
# 3     33.0  6486517.0  1617894.0  4090680.0  5464581.0  6122754.0  7446050.0
# 4     33.0  6672122.0  1322190.0  4496931.0  5818590.0  6485090.0  7655536.0
# 5     33.0  6983586.0  1557995.0  4187699.0  5712968.0  6759092.0  7971697.0
# 6     33.0  6409615.0  1704431.0  3687447.0  5183007.0  6177672.0  7672131.0
# 7     33.0  6413445.0  1644367.0  3649147.0  5173205.0  6268876.0  7614678.0
# 8     33.0  6422002.0  1449926.0  4139193.0  5450138.0  6045411.0  7223271.0
# 9     33.0  6438957.0  1560303.0  3987101.0  5335157.0  6008047.0  7712788.0
# 10    33.0  6290564.0  1381273.0  4233179.0  5251303.0  6209717.0  6926062.0
# 11    33.0  6561420.0  1465178.0  4034218.0  5411944.0  6171701.0  7743644.0
# ...

# %%
df_data.groupby(["week"])["Cost"].describe().round() #요일별
# Out:
#       count       mean        std        min        25%        50%        75%  \
# week
# 1     143.0  5868600.0  1043218.0  3545962.0  5185519.0  5714978.0  6254162.0
# 2     143.0  5730847.0   929953.0  3572868.0  5137953.0  5555467.0  6203751.0
# 3     144.0  5873140.0  1160172.0  3521456.0  5214632.0  5813806.0  6275264.0
# 4     144.0  5847080.0   890752.0  3649147.0  5208003.0  5899676.0  6447882.0
# 5     143.0  6274053.0  1000289.0  3598151.0  5723484.0  6315351.0  6951584.0
# 6     143.0  7795729.0  1321529.0  3937455.0  7280770.0  8077374.0  8635735.0
# 7     143.0  8463023.0  1183854.0  4362550.0  7876670.0  8664195.0  9208763.0
#
#              max
# week
# 1      9562016.0
# 2      8665646.0
# 3     12040631.0
# 4      8085034.0
# 5      8473764.0
# 6     10392834.0
# 7     10653581.0

# %%
df_data.groupby(["week"])["Cost"].mean().round()
# Out:
# week
# 1    5868600.0
# 2    5730847.0
# 3    5873140.0
# 4    5847080.0
# 5    6274053.0
# 6    7795729.0
# 7    8463023.0
# Name: Cost, dtype: float64

# %%
df_data.groupby(["Year"])["Cost"].mean().round()
# Out:
# Year
# 2019    6021240.0
# 2020    6466752.0
# 2021    6816716.0
# 2022    6864731.0
# Name: Cost, dtype: float64

# %%
df_data.groupby(["Month"])["Cost"].mean().round()
# Out:
# Month
# 1     6375550.0
# 2     6628139.0
# 3     6683738.0
# 4     6682726.0
# 5     6737818.0
# 6     6446247.0
# 7     6658590.0
# 8     7047088.0
# 9     6806593.0
# 10    6030676.0
# 11    5694009.0
# 12    6860402.0
# Name: Cost, dtype: float64

# %%
df_data.groupby(["Day"])["Cost"].mean().round()
# Out:
# Day
# 1     6531519.0
# 2     6374316.0
# 3     6486517.0
# 4     6672122.0
# 5     6983586.0
# 6     6409615.0
# 7     6413445.0
# 8     6422002.0
# 9     6438957.0
# 10    6290564.0
# 11    6561420.0
# 12    6811225.0
# 13    6646270.0
# 14    6687575.0
# 15    6499625.0
# 16    6324100.0
# 17    6179635.0
# 18    6383572.0
# 19    6675389.0
# 20    6574359.0
# 21    6627828.0
# 22    6534215.0
# 23    6587436.0
# 24    6559990.0
# 25    6412109.0
# 26    6910199.0
# 27    6705172.0
# 28    6666103.0
# 29    6492417.0
# 30    6488658.0
# 31    6721631.0
# Name: Cost, dtype: float64

# %%
df_data.groupby(["Year","Month"])["Cost"].mean().unstack().round() #년,월간평균표
# Out:
# Month         1          2          3          4          5          6   \
# Year
# 2019         NaN        NaN        NaN        NaN        NaN        NaN
# 2020   5456220.0  5783368.0  6576532.0  6392162.0  6465877.0  6362626.0
# 2021   6815179.0  7273914.0  6593765.0  6973289.0  7009759.0  6529868.0
# 2022   6855250.0  6857306.0  6880917.0        NaN        NaN        NaN
#
# Month         7          8          9          10         11         12
# Year
# 2019   6730989.0  6628407.0  5575084.0  5291947.0  4821958.0  7071766.0
# 2020   6215508.0  7139618.0  7545069.0  6226095.0  6269174.0  7147333.0
# 2021   7033944.0  7373239.0  7299626.0  6573985.0  5990896.0  6362108.0
# 2022         NaN        NaN        NaN        NaN        NaN        NaN

# %%
df_data.groupby(["Month","week"])["Cost"].mean().unstack().round() #월, 요일간 평균 1:월, 2:화 ... 6:토, 7:일
# Out:
# week           1          2          3          4          5          6  \
# Month
# 1      5221960.0  5450356.0  5635907.0  5757854.0  6227652.0  7751864.0
# 2      5524534.0  5639768.0  6264816.0  6064421.0  6307676.0  8039863.0
# 3      5892115.0  5836566.0  5972341.0  5861897.0  6388659.0  8345054.0
# 4      5371086.0  5426918.0  6223243.0  6075117.0  6633754.0  8276150.0
# 5      5523732.0  5873933.0  6317299.0  5800538.0  6240092.0  7989553.0
# 6      5314829.0  5407298.0  5813841.0  5702595.0  6307642.0  8006719.0
# 7      5607472.0  5740804.0  6232376.0  5875540.0  6429506.0  8135756.0
# 8      7285652.0  6141808.0  6053331.0  6354609.0  6710710.0  7769549.0
# 9      6622997.0  6049046.0  6077076.0  5888109.0  6552130.0  7861575.0
# 10     6284317.0  4925942.0  5066078.0  5420493.0  5917969.0  6974831.0
# 11     5532155.0  5782760.0  4817179.0  4890758.0  5083671.0  6453861.0
# 12     5674990.0  6272681.0  6154658.0  6384612.0  6654122.0  8418385.0
#
# week           7
# ...

# %%
def get_font_family():
    """
    시스템 환경에 따른 기본 폰트명을 반환하는 함수
    """
    import platform
    system_name = platform.system()

    if system_name == "Darwin" :
        font_family = "AppleGothic"
    elif system_name == "Windows":
        font_family = "Malgun Gothic"
    else:
        # Linux(colab)
        # !apt-get install fonts-nanum -qq  > /dev/null
        # !fc-cache -fv

        import matplotlib as mpl
        mpl.font_manager._rebuild()
        findfont = mpl.font_manager.fontManager.findfont
        mpl.font_manager.findfont = findfont
        mpl.backends.backend_agg.findfont = findfont
        
        font_family = "NanumBarunGothic"
    return font_family

# plt.rc("font", family=font_family)

# %%
import matplotlib.pyplot as plt
plt.rc("font", family = "Malgun Gothic")

# %%
g = df_data.groupby(["week"])["Cost"].mean() #요일별 평균판매량
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='week'>

# %%
g = df_data.groupby(["Year"])["Cost"].mean() #연도별 평균판매량
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
g = df_data.groupby(["Month"])["Cost"].mean() #월별 평균판매량 시각화
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
g = df_data.groupby(["Day"])["Cost"].mean() #일별 평균판매량 시각화
g.plot.bar(rot=0, figsize=(10,3))
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
df_data.groupby(["week"])["Cost"].mean().plot() #요일별 선차트
# Out:
# <AxesSubplot:xlabel='week'>

# %%
df_data.groupby(["Year"])["Cost"].mean().plot() #년도별 선차트
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df_data.groupby(["Month"])["Cost"].mean().plot() #월별 선차트
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df_data.groupby(["Day"])["Cost"].mean().plot() #일별 선차트
# Out:
# <AxesSubplot:xlabel='Day'>

# %%
df_data.pivot_table(index="Month",columns="week",values="Cost").plot.box() #월별, 일별 박스플롯
# Out:
# <AxesSubplot:>

# %%
p = df_data.pivot_table(index="Month",columns=["Year"],values="Cost")
p.plot.line(figsize=(20,3),rot= 50)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
import seaborn as sns
sns.catplot(data=df_data, x="week", y="Cost", kind="bar",col = "Month", col_wrap=4) #월별요일 요약

# %%
sns.boxplot(data=df_data, x="week", y="Cost")
# Out:
# <AxesSubplot:xlabel='week', ylabel='Cost'>

# %%
sns.lmplot(data=df_data, x="Year",y="Cost", hue="week", col="week", col_wrap=4)

# %%
price = df_data.loc[df_data["Cost"].notnull(),"Cost"]
sns.distplot(price)
# Out:
# <AxesSubplot:xlabel='Cost'>
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# subplot 으로 표현해 봅니다.
g = sns.FacetGrid(df_data, row="week", height = 1.7,
                  aspect=4,)
g.map(sns.distplot, "Cost", hist=False, rug=True)
# Out:
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
t = pd.pivot_table(df_data, index="Year", columns="week", values="Cost").round()
plt.figure(figsize=(15,7))
sns.heatmap(t, cmap="Blues", annot=True, fmt=".0f")
# Out:
# <AxesSubplot:xlabel='week', ylabel='Year'>

# %%
import pandas as pd
df_search=pd.read_csv("naver_data.csv", encoding="cp949")
df_search.shape
# Out:
# (1003, 6)

# %%
k = df_search.pivot_table(index="Month",columns=["Year"],values="Volume")
k.plot.line(figsize=(20,3),rot= 50)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
k = df_search.pivot_table(index="Week",columns=["Month"],values="Volume")
k.plot.line(figsize=(20,3),rot= 50)
# Out:
# <AxesSubplot:xlabel='Week'>

# %%
k = df_search.pivot_table(index="Week",columns=["Month"],values="Volume")
k.plot.line(figsize=(20,3),rot= 50)
# Out:
# <AxesSubplot:xlabel='Week'>

# %%
import seaborn as sns

t = pd.pivot_table(df_search, index="Year", columns="Week", values="Volume").round()
plt.figure(figsize=(15,7))
sns.heatmap(t, cmap="Blues", annot=True, fmt=".0f")
# Out:
# <AxesSubplot:xlabel='Week', ylabel='Year'>

# %%
import pandas as pd
df_real=pd.read_csv("real_data.csv", encoding="cp949")
df_real.shape
# Out:
# (1003, 20)

# %%
df_real
# Out:
#          癤풻ost  Year  Month  Day  Week  Holiday  Search  Promotion  Covid  \
# 0     12040631  2019      7    3     3        0   17000          2      1
# 1      7314019  2019      7    4     4        0   17200          2      1
# 2      7502285  2019      7    5     5        0   17400          2      1
# 3      8077689  2019      7    6     6        1   18800          2      1
# 4      8085593  2019      7    7     7        1   20400          2      1
# ...        ...   ...    ...  ...   ...      ...     ...        ...    ...
# 998    9395311  2022      3   27     7        1   32400          2      2
# 999    5636016  2022      3   28     1        0   32000          2      2
# 1000   6110748  2022      3   29     2        0   26300          2      2
# 1001   6202717  2022      3   30     3        0   25100          2      2
# 1002   6774187  2022      3   31     4        0   26900          2      2
#
#       avg_temp  low_temp  high_temp  day_rainfall  max_wind  avg_wind  \
# ...

# %%
df_real.corr()
# Out:
#                     癤풻ost      Year     Month       Day      Week   Holiday  \
# 癤풻ost            1.000000  0.190640 -0.045638  0.018975  0.589717  0.684306
# Year             0.190640  1.000000 -0.447853 -0.012937 -0.000362  0.005983
# Month           -0.045638 -0.447853  1.000000  0.010664 -0.005926 -0.013301
# Day              0.018975 -0.012937  0.010664  1.000000  0.000668 -0.015274
# Week             0.589717 -0.000362 -0.005926  0.000668  1.000000  0.724908
# Holiday          0.684306  0.005983 -0.013301 -0.015274  0.724908  1.000000
# Search           0.487817  0.240785 -0.177877 -0.005667  0.096831  0.284039
# Promotion        0.073160 -0.072032  0.139502  0.085120 -0.006796 -0.036872
# Covid            0.191131  0.642797 -0.049488  0.009388  0.000017  0.016114
# avg_temp         0.071936 -0.272884  0.261925  0.005211  0.017496  0.006307
# low_temp         0.075838 -0.278165  0.270508 -0.001534  0.015906  0.006552
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(df_real.corr())
# Out:
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\TFX5450H\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
import numpy as np
Q1 = np.percentile(df_data['Cost'],25)
Q3 = np.percentile(df_data['Cost'],75)
IQR = Q3-Q1
Q1-1.5*IQR, Q3+1.5*IQR
# Out:
# (2134305.0, 10898425.0)

# %%
outdata1 = df_data[df_data['Cost']<(Q1-1.5*IQR)]
outdata2 = df_data[df_data['Cost']>(Q3+1.5*IQR)]
len(outdata1), len(outdata2)
# Out:
# (0, 1)

# %%
outdata2['Cost']
# Out:
# 0    12040631
# Name: Cost, dtype: int64

# %%
outdata2[outdata2['Cost']==12040631]
# Out:
#          Date      Cost  Year  Month  Day  week
# 0  2019-07-03  12040631  2019      7    3     3

# %%
df_data['Cost'].mean()
# Out:
# 6548977.039880359

# %%
df_data['Cost'][df_data['week'==3]].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-92e8da9cef90> in <module>
# ...
